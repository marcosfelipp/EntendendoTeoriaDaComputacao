# %% [markdown]
# ### Máquina de Turing com Oráculo:
#
# Imagine uma máquina capaz de decidir algum problema e uma única operação. Este problema pode ser de qualquer classe de complexidade, até mesmo problemas indecidíveis, como o problema da parada.
#
# ![1443701-crystal_ball.jpg](attachment:1443701-crystal_ball.jpg)
